# %%
import pandas as pd

df = pd.read_csv('data_refined.csv')

# %%
df.head(5)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0    -0.351408     -0.835335       -0.324951  -0.393308
# 1          0     0.301824     -1.414775        0.234000   0.161860
# 2          0    -0.544538     -0.295456       -0.562618  -0.558835
# 3          0    -0.206561     -0.544452       -0.267285  -0.291490
# 4          0     0.673883     -0.232625        0.602652   0.521071
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0        -1.293808         -0.161864        0.285006            -0.387404
# 1        -1.190618         -0.663320       -0.688883            -0.576473
# 2        -0.288240         -0.617647       -0.563459            -0.738976
# 3        -1.209121         -0.897940       -0.841049            -0.881874
# 4         0.035563         -0.372605       -0.378900            -0.014681
#
#    symmetry_mean  fractal_dimension_mean
# 0      -1.385966               -0.488735
# ...

# %%
df.dropna()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            0    -0.351408     -0.835335       -0.324951  -0.393308
# 1            0     0.301824     -1.414775        0.234000   0.161860
# 2            0    -0.544538     -0.295456       -0.562618  -0.558835
# 3            0    -0.206561     -0.544452       -0.267285  -0.291490
# 4            0     0.673883     -0.232625        0.602652   0.521071
# ..         ...          ...           ...             ...        ...
# 564          1    -0.660984     -0.630553       -0.534609  -0.633919
# 565          1    -0.865474     -0.106963       -0.768981  -0.834144
# 566          1     0.563117     -0.288475        0.540867   0.449684
# 567          1     0.233661     -0.400174        0.201048   0.066014
# 568          1     1.097064     -2.073335        1.269934   0.984375
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            0    -0.351408     -0.835335       -0.324951  -0.393308
# 1            0     0.301824     -1.414775        0.234000   0.161860
# 2            0    -0.544538     -0.295456       -0.562618  -0.558835
# 3            0    -0.206561     -0.544452       -0.267285  -0.291490
# 4            0     0.673883     -0.232625        0.602652   0.521071
# ..         ...          ...           ...             ...        ...
# 564          1    -0.660984     -0.630553       -0.534609  -0.633919
# 565          1    -0.865474     -0.106963       -0.768981  -0.834144
# 566          1     0.563117     -0.288475        0.540867   0.449684
# 567          1     0.233661     -0.400174        0.201048   0.066014
# 568          1     1.097064     -2.073335        1.269934   0.984375
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df_corr = df.corrwith(df["diagnosis"])
df_corr
# Out:
# diagnosis                 1.000000
# radius_mean               0.730029
# texture_mean              0.415185
# perimeter_mean            0.742636
# area_mean                 0.708984
# smoothness_mean           0.358560
# compactness_mean          0.596534
# concavity_mean            0.696360
# concave points_mean       0.776614
# symmetry_mean             0.330499
# fractal_dimension_mean   -0.012838
# dtype: float64

# %%
for i in df_corr:
    if i>=0.6 and i<0.99:
        print(i)
# Out:
# 0.7300285113754555
# 0.7426355297258324
# 0.7089838365853893
# 0.6963597071719052
# 0.7766138400204347

# %%
feat = df[["diagnosis", "radius_mean", "perimeter_mean", "area_mean", "concavity_mean", "concave points_mean"]]
feat
# Out:
#      diagnosis  radius_mean  perimeter_mean  area_mean  concavity_mean  \
# 0            0    -0.351408       -0.324951  -0.393308        0.285006
# 1            0     0.301824        0.234000   0.161860       -0.688883
# 2            0    -0.544538       -0.562618  -0.558835       -0.563459
# 3            0    -0.206561       -0.267285  -0.291490       -0.841049
# 4            0     0.673883        0.602652   0.521071       -0.378900
# ..         ...          ...             ...        ...             ...
# 564          1    -0.660984       -0.534609  -0.633919        0.967997
# 565          1    -0.865474       -0.768981  -0.834144        1.005662
# 566          1     0.563117        0.540867   0.449684        0.071195
# 567          1     0.233661        0.201048   0.066014        0.817337
# 568          1     1.097064        1.269934   0.984375        2.652874
#
#      concave points_mean
# 0              -0.387404
# 1              -0.576473
# 2              -0.738976
# ...

# %%
y = feat["diagnosis"].values

x_columns = len(feat.columns)

x = feat.iloc[:, 0:x_columns].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
X_validate, X_test, y_validate, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=0)

# %%
print(len(X_train), len(X_test), len(X_validate))
# Out:
# 455 57 57

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3).fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier 
model = RandomForestClassifier(n_estimators=100, criterion='gini')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
score = model.score(X_test,y_test)
print(score)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
from sklearn import datasets
from sklearn.metrics import confusion_matrix
classifier = SVC(kernel='linear')
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
conf = confusion_matrix(y_test, y_pred)
print(conf)
score = classifier.score(X_test,y_test)
print(score)
# Out:
# [[35  0]
#  [ 0 22]]
# 1.0
